# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Diseases_and_Symptoms_dataset.csv")
print("Columns present in Disease_and Symptoms_dataset.csv - ",df.columns)
# Out:
# Columns present in Disease_and Symptoms_dataset.csv -  Index(['diseases', 'anxiety and nervousness', 'depression',
#        'shortness of breath', 'depressive or psychotic symptoms',
#        'sharp chest pain', 'dizziness', 'insomnia',
#        'abnormal involuntary movements', 'chest tightness',
#        ...
#        'sneezing', 'leg weakness', 'hysterical behavior', 'arm lump or mass',
#        'bleeding gums', 'pain in gums', 'diaper rash', 'hesitancy',
#        'back stiffness or tightness', 'low urine output'],
#       dtype='object', length=231)

# %%
df = pd.read_csv("/content/medications.csv")
print("Columns present in medications.csv - ",df.columns)
# Out:
# Columns present in medications.csv -  Index(['Disease', 'Medication'], dtype='object')

# %%
df = pd.read_csv("/content/description.csv")
print("Columns present in description.csv - ",df.columns)
# Out:
# Columns present in description.csv -  Index(['Disease', 'Description'], dtype='object')

# %%
df = pd.read_csv("/content/precautions.csv")
print("Columns present in precautions.csv - ",df.columns)
# Out:
# Columns present in precautions.csv -  Index(['Disease', 'Precaution_1', 'Precaution_2', 'Precaution_3',
#        'Precaution_4'],
#       dtype='object')

# %%
df = pd.read_csv("/content/workout.csv")
print("Columns present in workout.csv - ",df.columns)
# Out:
# Columns present in workout.csv -  Index(['Disease', 'Workouts'], dtype='object')

# %%
df = pd.read_csv("/content/diets.csv")
print("Columns present in diets.csv - ",df.columns)
# Out:
# Columns present in diets.csv -  Index(['Disease', 'Diet'], dtype='object')

# %%
df = pd.read_csv("/content/clinical_trials_2025_2026.csv")
print("Columns present in clinical_trails_2025_2026.csv - ",df.columns)
# Out:
# Columns present in clinical_trails_2025_2026.csv -  Index(['nct_id', 'title', 'status', 'phase', 'study_type', 'condition',
#        'intervention', 'sponsor', 'sponsor_class', 'start_date',
#        'completion_date', 'enrollment', 'country', 'has_results',
#        'brief_summary', 'duration_days', 'phase_numeric', 'enrollment_bucket',
#        'is_industry_sponsored', 'multi_country', 'condition_category',
#        'summary_word_count'],
#       dtype='object')
